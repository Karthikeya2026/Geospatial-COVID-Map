# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import geodatasets

# Load world countries map using geodatasets
world = gpd.read_file(geodatasets.get_path('naturalearth_lowres'))

# Sample COVID-19 data (simplified manually for demo purposes)
covid_data = pd.DataFrame({
    'country': ['China', 'United States of America', 'Brazil', 'India', 'Russia'],
    'cases': [90000, 500000, 400000, 300000, 200000]
})

# Merge world map with COVID data
merged = world.merge(covid_data, how='left', left_on='name', right_on='country')

# Plot
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
merged.plot(column='cases', cmap='Reds', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)

# Add title
plt.title('COVID-19 Cases by Country (Demo Map)', fontsize=15)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 7
#       4 import geodatasets
#       6 # Load world countries map using geodatasets
# ----> 7 world = gpd.read_file(geodatasets.get_path('naturalearth_lowres'))
#       9 # Sample COVID-19 data (simplified manually for demo purposes)
#      10 covid_data = pd.DataFrame({
#      11     'country': ['China', 'United States of America', 'Brazil', 'India', 'Russia'],
#      12     'cases': [90000, 500000, 400000, 300000, 200000]
#      13 })
#
# File ~\anaconda3\Lib\site-packages\geodatasets\api.py:86, in get_path(name)
#      49 def get_path(name):
#      50     """Get the absolute path to a file in the local storage.
#      51
#      52     If it’s not in the local storage, it will be downloaded.
#    (...)
#      84     '/Users/martin/Library/Caches/geodatasets/airbnb.zip'
#      85     """
# ...

# %%
pip install --upgrade geopandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geodatasets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import geodatasets

# Load world map using geodatasets
world = gpd.read_file(geodatasets.get_path('naturalearth.land'))
world.plot()
plt.show()
# Out:
# C:\Users\PHANI\anaconda3\Lib\site-packages\paramiko\pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# C:\Users\PHANI\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.Blowfish and will be removed from this module in 45.0.0.
#   "class": algorithms.Blowfish,
# C:\Users\PHANI\anaconda3\Lib\site-packages\paramiko\transport.py:243: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "class": algorithms.TripleDES,
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import geodatasets

# Optional: suppress those cryptography warnings
import warnings
from cryptography.utils import CryptographyDeprecationWarning
warnings.filterwarnings("ignore", category=CryptographyDeprecationWarning)

# Load world countries from geodatasets
world = gpd.read_file(geodatasets.get_path('naturalearth.countries'))

# Plot the map
world.plot(figsize=(12, 8), edgecolor='black')
plt.title("World Map - Natural Earth Countries", fontsize=16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 11
#       8 warnings.filterwarnings("ignore", category=CryptographyDeprecationWarning)
#      10 # Load world countries from geodatasets
# ---> 11 world = gpd.read_file(geodatasets.get_path('naturalearth.countries'))
#      13 # Plot the map
#      14 world.plot(figsize=(12, 8), edgecolor='black')
#
# File ~\anaconda3\Lib\site-packages\geodatasets\api.py:86, in get_path(name)
#      49 def get_path(name):
#      50     """Get the absolute path to a file in the local storage.
#      51
#      52     If it’s not in the local storage, it will be downloaded.
#    (...)
#      84     '/Users/martin/Library/Caches/geodatasets/airbnb.zip'
#      85     """
# ---> 86     dataset = data.query_name(name)
#      87     return dataset.path
#
# ...

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# Load the world shapefile (update the path to where you saved it!)
world = gpd.read_file(r'ne_10m_admin_0_countries.shp')

# Sample COVID-19 data (simplified manually for demo purposes)
covid_data = pd.DataFrame({
    'country': ['China', 'United States of America', 'Brazil', 'India', 'Russia'],
    'cases': [90000, 500000, 400000, 300000, 200000]
})

# Merge world map with COVID data
merged = world.merge(covid_data, how='left', left_on='NAME', right_on='country')

# Plot
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
merged.plot(column='cases', cmap='Reds', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)

# Add title
plt.title('COVID-19 Cases by Country (Demo Map)', fontsize=15)
plt.axis('off')
plt.show()
